# %% [markdown]
# # Feature Selection
# -Forward selection

# %%
from statistics import linear_regression
from warnings import filterwarnings
filterwarnings('ignore')

# %%
import pandas as pd
df = pd.read_csv('Datasets/Cars93.csv')
df.isna().sum()
# Out:
# Id                     0
# Manufacturer           0
# Model                  0
# Type                   0
# Min.Price              0
# Price                  0
# Max.Price              0
# MPG.city               0
# MPG.highway            0
# AirBags               37
# DriveTrain             0
# Cylinders              0
# EngineSize             0
# Horsepower             0
# RPM                    0
# Rev.per.mile           0
# Man.trans.avail        0
# Fuel.tank.capacity     0
# Passengers             0
# Length                 0
# Wheelbase              0
# Width                  0
# Turn.circle            0
# Rear.seat.room         2
# Luggage.room          11
# Weight                 0
# Origin                 0
# Make                   0
# dtype: int64

# %% [markdown]
# ### Seperate X and y features

# %%
X = df.drop(columns=['Id','Weight'])
Y = df[['Weight']]
X.head()
# Out:
#   Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0        Acura  Integra    Small       12.9   15.9       18.8        25
# 1        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2         Audi       90  Compact       25.9   29.1       32.3        20
# 3         Audi      100  Midsize       30.8   37.7       44.6        19
# 4          BMW     535i  Midsize       23.7   30.0       36.2        22
#
#    MPG.highway             AirBags DriveTrain  ... Fuel.tank.capacity  \
# 0           31                 NaN      Front  ...               13.2
# 1           25  Driver & Passenger      Front  ...               18.0
# 2           26         Driver only      Front  ...               16.9
# 3           26                 NaN      Front  ...               21.1
# 4           30         Driver only       Rear  ...               21.1
#
#    Passengers  Length  Wheelbase  Width Turn.circle  Rear.seat.room  \
# ...

# %%
Y.head()
# Out:
#    Weight
# 0    2705
# 1    3560
# 2    3375
# 3    3405
# 4    3640

# %%
from PM6func import catconsep
cat, con = catconsep(X)
cat
# Out:
# ['Manufacturer',
#  'Model',
#  'Type',
#  'AirBags',
#  'DriveTrain',
#  'Cylinders',
#  'Man.trans.avail',
#  'Origin',
#  'Make']

# %%
con
# Out:
# ['Min.Price',
#  'Price',
#  'Max.Price',
#  'MPG.city',
#  'MPG.highway',
#  'EngineSize',
#  'Horsepower',
#  'RPM',
#  'Rev.per.mile',
#  'Fuel.tank.capacity',
#  'Passengers',
#  'Length',
#  'Wheelbase',
#  'Width',
#  'Turn.circle',
#  'Rear.seat.room',
#  'Luggage.room']

# %%
X[con]
# Out:
#     Min.Price  Price  Max.Price  MPG.city  MPG.highway  EngineSize  \
# 0        12.9   15.9       18.8        25           31         1.8
# 1        29.2   33.9       38.7        18           25         3.2
# 2        25.9   29.1       32.3        20           26         2.8
# 3        30.8   37.7       44.6        19           26         2.8
# 4        23.7   30.0       36.2        22           30         3.5
# ..        ...    ...        ...       ...          ...         ...
# 88       16.6   19.7       22.7        17           21         2.5
# 89       17.6   20.0       22.4        21           30         2.0
# 90       22.9   23.3       23.7        18           25         2.8
# 91       21.8   22.7       23.5        21           28         2.3
# 92       24.8   26.7       28.5        20           28         2.4
#
#     Horsepower   RPM  Rev.per.mile  Fuel.tank.capacity  Passengers  Length  \
# 0          140  6300          2890                13.2           5     177
# ...

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OrdinalEncoder

# %%
num_pipeline = Pipeline(steps=[('impute',SimpleImputer(strategy='mean')),
                               ('scaler',StandardScaler())])
cat_pipeline = Pipeline(steps=[('impute',SimpleImputer(strategy='most_frequent')),
                               ('Ordinal',OrdinalEncoder())])
pre = ColumnTransformer([('num',num_pipeline,con),
                         ('cat',cat_pipeline,cat)])

# %%
X_pre = pre.fit_transform(X)
X_pre
# Out:
# array([[-0.48578741, -0.37572014, -0.28246529, ...,  1.        ,
#          1.        ,  0.        ],
#        [ 1.38801699,  1.49784409,  1.53140881, ...,  1.        ,
#          1.        ,  1.        ],
#        [ 1.00865782,  0.99822696,  0.94805231, ...,  1.        ,
#          1.        ,  3.        ],
#        ...,
#        [ 0.66378585,  0.39452293,  0.16416702, ...,  1.        ,
#          1.        , 87.        ],
#        [ 0.53733279,  0.33207079,  0.14593713, ...,  1.        ,
#          1.        , 91.        ],
#        [ 0.88220476,  0.7484184 ,  0.60168439, ...,  1.        ,
#          1.        , 92.        ]], shape=(93, 26))

# %%
cols = pre.get_feature_names_out()
cols
# Out:
# array(['num__Min.Price', 'num__Price', 'num__Max.Price', 'num__MPG.city',
#        'num__MPG.highway', 'num__EngineSize', 'num__Horsepower',
#        'num__RPM', 'num__Rev.per.mile', 'num__Fuel.tank.capacity',
#        'num__Passengers', 'num__Length', 'num__Wheelbase', 'num__Width',
#        'num__Turn.circle', 'num__Rear.seat.room', 'num__Luggage.room',
#        'cat__Manufacturer', 'cat__Model', 'cat__Type', 'cat__AirBags',
#        'cat__DriveTrain', 'cat__Cylinders', 'cat__Man.trans.avail',
#        'cat__Origin', 'cat__Make'], dtype=object)

# %%
X_pre = pd.DataFrame(X_pre,columns=[cols])
X_pre.head()
# Out:
#   num__Min.Price num__Price num__Max.Price num__MPG.city num__MPG.highway  \
# 0      -0.485787  -0.375720      -0.282465      0.471312         0.360925
# 1       1.388017   1.497844       1.531409     -0.781032        -0.770514
# 2       1.008658   0.998227       0.948052     -0.423219        -0.581941
# 3       1.571949   1.893374       2.069191     -0.602126        -0.581941
# 4       0.755752   1.091905       1.303535     -0.065407         0.172352
#
#   num__EngineSize num__Horsepower  num__RPM num__Rev.per.mile  \
# 0       -0.841022       -0.073484  1.717489          1.129530
# 1        0.515869        1.078322  0.369586          0.005661
# 2        0.128186        0.540813  0.369586         -0.105713
# 3        0.128186        0.540813  0.369586          0.410659
# 4        0.806631        1.231897  0.706562          0.430909
#
#   num__Fuel.tank.capacity  ... num__Luggage.room cat__Manufacturer cat__Model  \
# ...

# %% [markdown]
# ### Feature Selection Forward with SequentialFeatureSelector

# %%
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
sel = SequentialFeatureSelector(model, direction='forward')
sel_features = sel.fit_transform(X_pre, Y)
sel_cols = sel.get_feature_names_out(cols)
sel_cols
# Out:
# array(['num__MPG.highway', 'num__Horsepower', 'num__RPM',
#        'num__Fuel.tank.capacity', 'num__Passengers', 'num__Length',
#        'num__Wheelbase', 'num__Width', 'num__Rear.seat.room',
#        'cat__Manufacturer', 'cat__Type', 'cat__Cylinders', 'cat__Origin'],
#       dtype=object)

# %%
sel_cols[0]
# Out:
# 'num__MPG.highway'

# %%
sel_cols[0].split('__')
# Out:
# ['num', 'MPG.highway']

# %%
imp_cols = []
for col in sel_cols:
    imp_cols.append(col.split('__')[1])
imp_cols
# Out:
# ['MPG.highway',
#  'Horsepower',
#  'RPM',
#  'Fuel.tank.capacity',
#  'Passengers',
#  'Length',
#  'Wheelbase',
#  'Width',
#  'Rear.seat.room',
#  'Manufacturer',
#  'Type',
#  'Cylinders',
#  'Origin']

# %% [markdown]
# # Feature Selection in X

# %%
X_sel = X[imp_cols]
X_sel.head()
# Out:
#    MPG.highway  Horsepower   RPM  Fuel.tank.capacity  Passengers  Length  \
# 0           31         140  6300                13.2           5     177
# 1           25         200  5500                18.0           5     195
# 2           26         172  5500                16.9           5     180
# 3           26         172  5500                21.1           6     193
# 4           30         208  5700                21.1           4     186
#
#    Wheelbase  Width  Rear.seat.room Manufacturer     Type Cylinders   Origin
# 0        102     68            26.5        Acura    Small         4  non-USA
# 1        115     71            30.0        Acura  Midsize         6  non-USA
# 2        102     67            28.0         Audi  Compact         6  non-USA
# 3        106     70            31.0         Audi  Midsize         6  non-USA
# 4        109     69            27.0          BMW  Midsize         4  non-USA

# %%
xselcat, xselcon = catconsep(X_sel)
xselcat
# Out:
# ['Manufacturer', 'Type', 'Cylinders', 'Origin']

# %%
xselcon
# Out:
# ['MPG.highway',
#  'Horsepower',
#  'RPM',
#  'Fuel.tank.capacity',
#  'Passengers',
#  'Length',
#  'Wheelbase',
#  'Width',
#  'Rear.seat.room']

# %%
X_sel[xselcon]
# Out:
#     MPG.highway  Horsepower   RPM  Fuel.tank.capacity  Passengers  Length  \
# 0            31         140  6300                13.2           5     177
# 1            25         200  5500                18.0           5     195
# 2            26         172  5500                16.9           5     180
# 3            26         172  5500                21.1           6     193
# 4            30         208  5700                21.1           4     186
# ..          ...         ...   ...                 ...         ...     ...
# 88           21         109  4500                21.1           7     187
# 89           30         134  5800                18.5           5     180
# 90           25         178  5800                18.5           4     159
# 91           28         114  5400                15.8           5     190
# 92           28         168  6200                19.3           5     184
#
#     Wheelbase  Width  Rear.seat.room
# 0         102     68            26.5
# ...

# %% [markdown]
# ## Create Pipeline for X selected Feature

# %%
num_pipeline2 = Pipeline(steps=[('impute',SimpleImputer(strategy='mean')),
                                ('scaler',StandardScaler())])
cat_pipeline2 = Pipeline(steps=[('impute',SimpleImputer(strategy='most_frequent')),
                                ('ordinal',OrdinalEncoder())])
X_pre2 = ColumnTransformer([('num',num_pipeline2,xselcon),
                            ('cat',cat_pipeline2,xselcat)])
X_pre2
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('impute', SimpleImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  ['MPG.highway', 'Horsepower', 'RPM',
#                                   'Fuel.tank.capacity', 'Passengers', 'Length',
#                                   'Wheelbase', 'Width', 'Rear.seat.room']),
#                                 ('cat',
#                                  Pipeline(steps=[('impute',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('ordinal',
#                                                   OrdinalEncoder())]),
#                                  ['Manufacturer', 'Type', 'Cylinders',
#                                   'Origin'])])

# %%
x_sel_pre = X_pre2.fit_transform(X_sel)
x_sel_pre
# Out:
# array([[ 0.36092485, -0.07348445,  1.71748854, ...,  3.        ,
#          1.        ,  1.        ],
#        [-0.77051373,  1.07832243,  0.36958614, ...,  2.        ,
#          3.        ,  1.        ],
#        [-0.58194063,  0.54081255,  0.36958614, ...,  0.        ,
#          3.        ,  1.        ],
#        ...,
#        [-0.77051373,  0.65599324,  0.87504954, ...,  4.        ,
#          3.        ,  1.        ],
#        [-0.20479444, -0.57260077,  0.20109834, ...,  0.        ,
#          1.        ,  1.        ],
#        [-0.20479444,  0.46402543,  1.54900074, ...,  2.        ,
#          2.        ,  1.        ]], shape=(93, 13))

# %%
final_cols = X_pre2.get_feature_names_out()
final_cols
# Out:
# array(['num__MPG.highway', 'num__Horsepower', 'num__RPM',
#        'num__Fuel.tank.capacity', 'num__Passengers', 'num__Length',
#        'num__Wheelbase', 'num__Width', 'num__Rear.seat.room',
#        'cat__Manufacturer', 'cat__Type', 'cat__Cylinders', 'cat__Origin'],
#       dtype=object)

# %%
X_final = pd.DataFrame(x_sel_pre,columns=[final_cols])
X_final.head()
# Out:
#   num__MPG.highway num__Horsepower  num__RPM num__Fuel.tank.capacity  \
# 0         0.360925       -0.073484  1.717489               -1.062184
# 1        -0.770514        1.078322  0.369586                0.409445
# 2        -0.581941        0.540813  0.369586                0.072197
# 3        -0.581941        0.540813  0.369586                1.359872
# 4         0.172352        1.231897  0.706562                1.359872
#
#   num__Passengers num__Length num__Wheelbase num__Width num__Rear.seat.room  \
# 0       -0.083243   -0.427186      -0.286932  -0.366184           -0.452197
# 1       -0.083243    0.812171       1.629649   0.431983            0.738090
# 2       -0.083243   -0.220626      -0.286932  -0.632239            0.057926
# 3        0.884457    0.674465       0.302785   0.165927            1.078172
# 4       -1.050944    0.192493       0.745073  -0.100128           -0.282156
#
#   cat__Manufacturer cat__Type cat__Cylinders cat__Origin
# ...

# %% [markdown]
# ### Train Test Split
# 1. 80% train data
# 2. 20% test data

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(X_final, Y, test_size=0.2, random_state=21)

# %%
xtrain.head()
# Out:
#    num__MPG.highway num__Horsepower  num__RPM num__Fuel.tank.capacity  \
# 57        -0.016221       -0.265452 -0.304365               -0.663618
# 31         0.172352       -0.323043  2.054464               -1.062184
# 62        -0.959087        1.116716  1.212025                0.716035
# 29        -0.204794        1.347077  0.875050                0.409445
# 51        -0.581941        1.270290 -1.146804                1.022624
#
#    num__Passengers num__Length num__Wheelbase num__Width num__Rear.seat.room  \
# 57       -0.083243   -0.564892       0.155356  -0.632239           -0.622238
# 31       -0.083243   -0.840305      -0.876650  -0.632239            0.057926
# 62       -0.083243    0.467905       0.450214   0.165927           -0.112115
# 29        0.884457    1.294143       1.334791   1.230149            0.738090
# 51        0.884457    2.464647       1.924508   2.028316            1.248213
#
#    cat__Manufacturer cat__Type cat__Cylinders cat__Origin
# ...

# %%
ytrain.head()
# Out:
#     Weight
# 57    2920
# 31    2530
# 62    3730
# 29    3490
# 51    4055

# %%
model = LinearRegression()
model.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
ypred_tr = model.predict(xtrain)
ypred_ts = model.predict(xtest)
ypred_ts[0:5]
# Out:
# array([[2581.44952638],
#        [3761.18757983],
#        [2978.83732903],
#        [3229.5224113 ],
#        [3962.58918808]])

# %%
ytest.head()
# Out:
#     Weight
# 23    2670
# 86    3785
# 91    2985
# 21    3570
# 17    3910

# %%
ypred_tr[0:5]
# Out:
# array([[3063.47747267],
#        [2433.51381656],
#        [3492.68608589],
#        [3620.59773558],
#        [4040.0761348 ]])

# %%
ytrain.head()
# Out:
#     Weight
# 57    2920
# 31    2530
# 62    3730
# 29    3490
# 51    4055

# %% [markdown]
# R2Score of train and test model

# %%
model.score(xtrain, ytrain)
# Out:
# 0.9692819365465895

# %%
model.score(xtest, ytest)
# Out:
# 0.935031543354987
