# %% [markdown]
# # Simple linear regression
# on salary datasets

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from warnings import filterwarnings

# %%
filterwarnings('ignore')

# %%
df= pd.read_csv('Datasets\Salary_dataset.csv')
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
X = df[['YearsExperience']]
Y = df[['Salary']]
plt.scatter(X,Y)
plt.show()

# %% [markdown]
# Train Model

# %%
model = LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
model.score(X,Y)
# Out:
# 0.9569566641435086

# %%
y_pred = model.predict(X)
y_pred[0:5]
# Out:
# array([[36188.15875227],
#        [38078.15121656],
#        [39968.14368085],
#        [44693.12484158],
#        [46583.11730587]])

# %%
Y[0:5]
# Out:
#     Salary
# 0  39344.0
# 1  46206.0
# 2  37732.0
# 3  43526.0
# 4  39892.0

# %% [markdown]
# 1. Mean Absolute Error
# 2. Mean Squared Error
# 3. Root Mean Squared error
# 4. R2Score

# %%
mse = mean_squared_error(Y,y_pred)
mse
# Out:
# 31270951.722280957

# %%
mae = mean_absolute_error(Y,y_pred)
mae
# Out:
# 4644.2012894435375

# %%
r2 = r2_score(Y,y_pred)
r2
# Out:
# 0.9569566641435086

# %% [markdown]
# ### Coeficent and Intercept

# %%
model.coef_
# Out:
# array([[9449.96232146]])

# %%
model.intercept_
# Out:
# array([24848.20396652])

# %%
X = [[3.0]]
Salary_pred = model.predict(X)
Salary_pred
# Out:
# array([[53198.09093089]])

# %% [markdown]
# ### Regeression Line

# %%
sns.regplot(data=df, x = 'YearsExperience', y = 'Salary', line_kws={'color':'red'}, scatter_kws={'color':'blue'})
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>
