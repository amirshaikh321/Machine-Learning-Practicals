# %% [markdown]
# # Simple Linear Regression
# scikit-learn

# %% [markdown]
# ### Upgrade Scikit-learn

# %%
# %pip install scikit-learn --upgrade --user
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Can not perform a '--user' install. User site-packages are not visible in this virtualenv.

# %%
from warnings import filterwarnings
filterwarnings("ignore")

# %%
import pandas as pd
df = pd.read_csv("Datasets\HOUSEPRICE.csv")
df
# Out:
#    Area   Price
# 0  1000  150000
# 1  1500  200000
# 2  1800  220000
# 3  2400  280000
# 4  3000  350000
# 5  1200  130000
# 6  2000  250000
# 7  2500  270000
# 8  2750  330000
# 9  3200  400000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Area    10 non-null     int64
#  1   Price   10 non-null     int64
# dtypes: int64(2)
# memory usage: 292.0 bytes

# %%
import matplotlib.pyplot as plt
plt.scatter(df[['Area']],df[['Price']])
plt.xlabel("Area")
plt.ylabel("Price")
plt.show()

# %%
from sklearn.linear_model import LinearRegression

model= LinearRegression()

# %%
X = df[["Area"]]
Y = df[["Price"]]
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)
y_pred
# Out:
# array([[130824.57245289],
#        [186848.98987452],
#        [220463.6403275 ],
#        [287692.94123347],
#        [354922.24213943],
#        [153234.33942154],
#        [242873.40729616],
#        [298897.82471779],
#        [326910.03342861],
#        [377332.00910809]])

# %%
Y
# Out:
#     Price
# 0  150000
# 1  200000
# 2  220000
# 3  280000
# 4  350000
# 5  130000
# 6  250000
# 7  270000
# 8  330000
# 9  400000

# %% [markdown]
# ### Coeficient and Interept

# %%
model.coef_
# Out:
# array([[112.04883484]])

# %%
model.intercept_
# Out:
# array([18775.73760961])

# %% [markdown]
# ### Price_pred = 18775.73 + 112.04 * area
# checking R2score

# %%
model.score(X,Y)
# Out:
# 0.9617968572799956

# %% [markdown]
# ### Perform other evaluation on model
# 1. Mean Squared Error
# 2. Mean Absolute Error
# 3. R2Score
# 4. Root Mean Squared Error

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

mse = mean_squared_error(Y,y_pred)
mse
# Out:
# 257336369.3619493

# %%
mae = mean_absolute_error(Y,y_pred)
mae
# Out:
# 13042.197567947283

# %%
rmse = mse**(1/2)
rmse
# Out:
# 16041.70718352474

# %% [markdown]
# ### Use of model
# 1. Predict the price by Area of house
# 2. Check the relation between the values

# %%
X= [[4000]]
Price_pred = model.predict(X)
Price_pred
# Out:
# array([[466971.0769827]])

# %% [markdown]
# ### Checking how line is fitted

# %%
import seaborn as sns
sns.regplot(data=df, x="Area", y="Price", line_kws={'color':'red'}, scatter_kws={'color':'blue'})
# Out:
# <Axes: xlabel='Area', ylabel='Price'>
